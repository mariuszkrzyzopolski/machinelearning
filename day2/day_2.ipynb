# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Nowa komórka esc + A

# %%
np.random.rand(3,2)
# Out:
# array([[0.02621049, 0.74890976],
#        [0.46000486, 0.54688411],
#        [0.83303512, 0.73564312]])

# %%
# %matplotlib inline
x = np.linspace(1, 10, 100)
y = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
plt.plot(x,y)
plt.plot(x,y2)
plt.plot(x,y3)
